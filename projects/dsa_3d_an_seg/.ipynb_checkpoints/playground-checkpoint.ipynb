# %% [markdown]
# ### 第一批数据 20190628

# %%
from main import *
# Out:
# Using TensorFlow backend.

# %%
image_path ='/data/maze/3D_An_Seg_20190628/01.CVAImage/'
an_path = '/data/maze/3D_An_Seg_20190628/03.Aneurysms/'
vessel_path = '/data/maze/3D_An_Seg_20190628/02.CVAVesselMask/'
save_path = '/home/maze/USAL/libs/data'

(x_train, labels_train), (x_test, labels_test), (x_val, labels_val), data_seperate = generate_data(ImageIo, NumpyIo, data_load_path, drop_data_list = drop_data_list, block_size = 64, save = True, save_path = save_path)
# Out:
# load data from the source dir:  ['/data/maze/3D_An_Seg_20190628/01.CVAImage/', '/data/maze/3D_An_Seg_20190628/03.Aneurysms/', '/data/maze/3D_An_Seg_20190628/02.CVAVesselMask/']
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000002.T0001Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000005.T0001Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000006.T0002Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000009.T0002Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000012.T0001Aneurysms.mha
# an #:  1
# an #:  2
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000018.T0001Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000022.T0001Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000023.T0001Aneurysms.mha
# an #:  1
# an #:  2
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000024.T0003Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000033.T0001Aneurysms.mha
# an #:  1
# an #:  2
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000036.T0001Aneurysms.mha
# an #:  1
# an #:  2
# an #:  3
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000037.T0002Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000039.T0001Aneurysms.mha
# an #:  1
# an #:  2
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000045.T0001Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000046.T0001Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000048.T0001Aneurysms.mha
# an #:  1
# an #:  2
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000052.T0002Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000054.T0001Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000054.T0002Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000055.T0006Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000056.T0001Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000057.T0001Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000058.T0001Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000059.T0001Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000063.T0001Aneurysms.mha
# an #:  1
# an #:  2
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000064.T0001Aneurysms.mha
# an #:  1
# an #:  2
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000064.T0002Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000065.T0001Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000065.T0002Aneurysms.mha
# an #:  1
# an #:  2
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000066.T0002Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000067.T0002Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000068.T0001Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000069.T0003Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000072.T0001Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000073.T0001Aneurysms.mha
# an #:  1
# an #:  2
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000075.T0002Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000082.T0001Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000083.T0001Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000084.T0001Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000086.T0001Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000088.T0001Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000089.T0001Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000094.T0001Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000095.T0001Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000097.T0001Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000098.T0001Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000105.T0001Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000109.T0001Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000112.T0001Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000114.T0002Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000115.T0002Aneurysms.mha
# an #:  1
# an #:  2
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000117.T0001Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000122.T0002Aneurysms.mha
# an #:  1
# an #:  2
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000123.T0001Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000127.T0001Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000128.T0001Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000132.T0001Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000133.T0002Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000135.T0002Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000136.T0001Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000143.T0002Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000147.T0001Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000155.T0001Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000156.T0001Aneurysms.mha
# an #:  1
# an #:  2
# an #:  3
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000164.T0001Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000168.T0001Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000176.T0001Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000183.T0001Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000184.T0001Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000185.T0001Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000186.T0001Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000187.T0002Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000188.T0001Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000193.T0002Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000194.T0002Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000195.T0001Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000196.T0001Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000206.T0001Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000209.T0001Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000216.T0001Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000218.T0001Aneurysms.mha
# an #:  1
# an #:  2
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000223.T0001Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000224.T0003Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000225.T0001Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000229.T0001Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000232.T0001Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000234.T0002Aneurysms.mha
# an #:  1
# an #:  2
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000235.T0003Aneurysms.mha
# an #:  1
# an #:  2
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000239.T0001Aneurysms.mha
# an #:  1
# an #:  2
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000242.T0002Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000243.T0001Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000244.T0003Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000246.T0001Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000248.T0001Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000254.T0001Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000258.T0002Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000259.T0001Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000262.T0001Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000264.T0001Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000265.T0005Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000266.T0001Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000267.T0005Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000268.T0001Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000268.T0002Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000269.T0001Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000274.T0001Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000275.T0001Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000275.T0002Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000276.T0001Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000277.T0001Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000278.T0001Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000282.T0001Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000285.T0001Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000289.T0002Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000293.T0001Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000297.T0002Aneurysms.mha
# an #:  1
# an #:  2
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000299.T0001Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000304.T0001Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000315.T0002Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000315.T0003Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000319.T0001Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000323.T0001Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000326.T0001Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000328.T0001Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000338.T0004Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000353.T0001Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000367.T0001Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000368.T0001Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000375.T0001Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000376.T0001Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000405.T0001Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000416.T0001Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000427.T0001Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000435.T0001Aneurysms.mha
# an #:  1
# an #:  2
# an #:  3
# an #:  4
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000454.T0002Aneurysms.mha
# an #:  1
# an #:  2
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000463.T0002Aneurysms.mha
# an #:  1
# an #:  2
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000473.T0001Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000477.T0001Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000538.T0001Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000539.T0001Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000564.T0001Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000564.T0002Aneurysms.mha
# an #:  1
# an #:  2
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000568.T0001Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000579.T0001Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000596.T0001Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000604.T0001Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000613.T0002Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000659.T0001Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000684.T0001Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000696.T0001Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000707.T0001Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000709.T0001Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000723.T0001Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000738.T0001Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000753.T0001Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000757.T0001Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000766.T0001Aneurysms.mha
# an #:  1
# an #:  2
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000784.T0001Aneurysms.mha
# an #:  1
# an #:  2
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000795.T0001Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000802.T0001Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000021.T0002Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000031.T0002Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000031.T0005Aneurysms.mha
# an #:  1
# an #:  2
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000041.T0002Aneurysms.mha
# an #:  1
# an #:  2
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000051.T0002Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000071.T0001Aneurysms.mha
# an #:  1
# an #:  2
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000091.T0001Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000131.T0002Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000161.T0002Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000191.T0001Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000191.T0002Aneurysms.mha
# an #:  1
# an #:  2
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000201.T0002Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000211.T0001Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000211.T0002Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000231.T0002Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000241.T0001Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000241.T0002Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000251.T0002Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000281.T0001Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000291.T0001Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000321.T0001Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000321.T0002Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000441.T0002Aneurysms.mha
# an #:  1
# an #:  2
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000741.T0002Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000010.T0001Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000030.T0001Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000070.T0001Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000090.T0001Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000110.T0001Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000140.T0001Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000150.T0001Aneurysms.mha
# an #:  1
# an #:  2
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000160.T0001Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000180.T0002Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000190.T0001Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000200.T0001Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000210.T0003Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000280.T0001Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000480.T0001Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000540.T0002Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000600.T0002Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000620.T0001Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000640.T0001Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000650.T0001Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000660.T0001Aneurysms.mha
# an #:  1
# processing:  /data/maze/3D_An_Seg_20190628/03.Aneurysms/A002.P000660.T0002Aneurysms.mha
# an #:  1
# x_train.npy  saved to:  /home/maze/USAL/libs/data
# labels_train.npy  saved to:  /home/maze/USAL/libs/data
# x_test.npy  saved to:  /home/maze/USAL/libs/data
# labels_test.npy  saved to:  /home/maze/USAL/libs/data
# x_val.npy  saved to:  /home/maze/USAL/libs/data
# labels_val.npy  saved to:  /home/maze/USAL/libs/data
# data_seperate.npy  saved to:  /home/maze/USAL/libs/data

# %% [markdown]
# ### 第二批数据 20191202

# %%
from main import *
# Out:
# Using TensorFlow backend.

# %%
image_path ='/data/maze/04.AN-AI/01.CVAImage/'
an_path = '/data/maze/04.AN-AI/03.Aneurysms/'
vessel_path = '/data/maze/04.AN-AI/02.CVAVesselMask/'
save_path = '/home/maze/USAL/libs/new_data'

(x_train, labels_train), (x_test, labels_test), (x_val, labels_val), data_seperate = generate_data(ImageIo, NumpyIo, image_path, an_path, vessel_path, drop_list, block_size = 64, save = True, save_path = save_path)
# Out:
# load img from the source dir:  /data/maze/04.AN-AI/01.CVAImage/
# A002.P000208 dropped!
# A003.P000143 dropped!
# load an from the source dir:  /data/maze/04.AN-AI/03.Aneurysms/
# A002.P000208 dropped!
# A003.P000143 dropped!
# load vessel from the source dir:  /data/maze/04.AN-AI/02.CVAVesselMask/
# A002.P000208 dropped!
# A003.P000143 dropped!
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000002.D01.S003Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000005.D01.S001Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000006.D01.S001Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000009.D01.S003Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000012.D01.S001Aneurysms.mha
# an #:  1
# an #:  2
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000018.D01.S001Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000022.D01.S004Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000023.D01.S004Aneurysms.mha
# an #:  1
# an #:  2
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000024.D01.S002Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000033.D01.S001Aneurysms.mha
# an #:  1
# an #:  2
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000036.D01.S003Aneurysms.mha
# an #:  1
# an #:  2
# an #:  3
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000037.D01.S001Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000039.D01.S005Aneurysms.mha
# an #:  1
# an #:  2
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000045.D01.S005Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000046.D01.S001Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000048.D01.S002Aneurysms.mha
# an #:  1
# an #:  2
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000052.D01.S001Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000054.D01.S001Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000054.D01.S003Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000055.D01.S003Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000056.D01.S004Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000057.D01.S001Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000058.D01.S001Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000059.D01.S002Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000063.D01.S002Aneurysms.mha
# an #:  1
# an #:  2
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000064.D01.S001Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000064.D01.S004Aneurysms.mha
# an #:  1
# an #:  2
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000065.D01.S001Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000065.D01.S004Aneurysms.mha
# an #:  1
# an #:  2
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000066.D01.S001Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000067.D01.S004Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000068.D01.S003Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000069.D01.S003Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000072.D01.S002Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000073.D01.S002Aneurysms.mha
# an #:  1
# an #:  2
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000075.D01.S007Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000082.D01.S002Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000083.D01.S001Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000084.D01.S004Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000086.D01.S001Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000088.D01.S003Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000089.D01.S002Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000094.D01.S003Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000095.D01.S002Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000097.D01.S003Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000098.D01.S004Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000105.D01.S002Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000105.D01.S007Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000109.D01.S003Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000112.D01.S001Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000114.D01.S002Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000115.D01.S001Aneurysms.mha
# an #:  1
# an #:  2
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000117.D01.S002Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000122.D01.S002Aneurysms.mha
# an #:  1
# an #:  2
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000123.D01.S001Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000127.D01.S001Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000128.D01.S001Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000132.D01.S003Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000133.D01.S004Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000135.D01.S005Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000136.D01.S002Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000143.D01.S003Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000147.D01.S002Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000155.D01.S002Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000156.D01.S002Aneurysms.mha
# an #:  1
# an #:  2
# an #:  3
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000164.D01.S003Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000168.D01.S001Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000176.D01.S002Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000183.D01.S003Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000184.D01.S001Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000185.D01.S003Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000186.D01.S003Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000187.D01.S002Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000188.D01.S003Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000193.D01.S001Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000194.D01.S002Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000195.D01.S001Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000196.D01.S004Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000206.D01.S001Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000209.D01.S002Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000216.D01.S001Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000218.D01.S003Aneurysms.mha
# an #:  1
# an #:  2
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000223.D01.S001Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000224.D01.S003Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000225.D01.S002Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000229.D01.S002Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000232.D01.S004Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000234.D01.S002Aneurysms.mha
# an #:  1
# an #:  2
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000235.D01.S002Aneurysms.mha
# an #:  1
# an #:  2
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000239.D01.S003Aneurysms.mha
# an #:  1
# an #:  2
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000242.D01.S002Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000243.D01.S001Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000244.D01.S004Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000246.D01.S002Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000248.D01.S003Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000254.D01.S002Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000258.D01.S001Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000259.D01.S001Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000262.D01.S001Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000264.D01.S003Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000265.D01.S003Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000266.D01.S002Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000267.D01.S004Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000268.D01.S001Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000268.D01.S002Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000269.D01.S002Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000274.D01.S001Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000275.D01.S001Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000275.D01.S002Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000276.D01.S001Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000277.D01.S003Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000278.D01.S003Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000282.D01.S001Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000285.D01.S001Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000289.D01.S003Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000293.D01.S001Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000299.D01.S002Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000304.D01.S002Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000315.D01.S001Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000315.D01.S004Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000319.D01.S003Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000323.D01.S003Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000326.D01.S001Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000328.D01.S003Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000338.D02.S004Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000353.D01.S003Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000367.D01.S002Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000368.D01.S002Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000375.D01.S001Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000376.D02.S001Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000405.D01.S002Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000416.D01.S003Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000427.D01.S002Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000435.D01.S002Aneurysms.mha
# an #:  1
# an #:  2
# an #:  3
# an #:  4
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000454.D02.S001Aneurysms.mha
# an #:  1
# an #:  2
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000463.D01.S004Aneurysms.mha
# an #:  1
# an #:  2
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000473.D01.S004Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000477.D01.S004Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000538.D01.S001Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000539.D01.S001Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000564.D01.S002Aneurysms.mha
# an #:  1
# an #:  2
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000564.D01.S003Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000568.D01.S007Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000579.D01.S002Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000596.D01.S002Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000604.D01.S002Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000613.D01.S001Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000659.D01.S005Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000684.D01.S003Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000696.D01.S003Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000707.D01.S001Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000709.D01.S003Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000723.D01.S004Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000738.D01.S003Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000753.D01.S001Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000757.D01.S002Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000766.D01.S002Aneurysms.mha
# an #:  1
# an #:  2
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000784.D02.S008Aneurysms.mha
# an #:  1
# an #:  2
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000795.D01.S002Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000802.D01.S001Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000809.D01.S006Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000812.D01.S003Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000813.D01.S001Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000813.D01.S003Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000814.D01.S001Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000815.D01.S002Aneurysms.mha
# an #:  1
# an #:  2
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000817.D01.S001Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000817.D01.S003Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000818.D01.S004Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000822.D01.S003Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000822.D01.S005Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000822.D01.S009Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000823.D01.S001Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000824.D01.S001Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000825.D01.S001Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000826.D01.S001Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000827.D01.S001Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000827.D01.S004Aneurysms.mha
# an #:  1
# an #:  2
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000828.D01.S004Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000829.D01.S004Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000834.D01.S005Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000834.D01.S006Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000835.D01.S005Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000835.D01.S008Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000835.D01.S010Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000836.D01.S003Aneurysms.mha
# an #:  1
# an #:  2
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000838.D01.S001Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000839.D01.S002Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000839.D01.S003Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000839.D01.S004Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000842.D01.S004Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000843.D01.S002Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000844.D01.S003Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000845.D01.S002Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000846.D01.S002Aneurysms.mha
# an #:  1
# an #:  2
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000848.D01.S002Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000849.D01.S003Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000853.D01.S001Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000857.D01.S002Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000858.D01.S001Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000859.D01.S001Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000862.D01.S003Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000866.D01.S005Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000868.D01.S001Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000869.D01.S001Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000873.D01.S002Aneurysms.mha
# an #:  1
# an #:  2
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000873.D01.S003Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000873.D01.S007Aneurysms.mha
# an #:  1
# an #:  2
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000874.D01.S003Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000878.D01.S003Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000879.D01.S001Aneurysms.mha
# an #:  1
# an #:  2
# an #:  3
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000882.D01.S003Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000892.D01.S003Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000895.D01.S002Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000897.D01.S005Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000897.D01.S012Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000899.D01.S005Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000902.D01.S001Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000904.D01.S002Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000906.D01.S001Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000907.D01.S008Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000908.D01.S002Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000918.D01.S020Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000919.D01.S001Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P001343.D02.S017Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A003.P000002.D01.S001Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A003.P000003.D01.S002Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A003.P000003.D01.S004Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A003.P000004.D02.S001Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A003.P000005.D02.S001Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A003.P000006.D01.S001Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A003.P000007.D01.S001Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A003.P000008.D01.S001Aneurysms.mha
# an #:  1
# an #:  2
# an #:  3
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A003.P000009.D01.S002Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A003.P000012.D01.S001Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A003.P000012.D01.S004Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A003.P000013.D01.S001Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A003.P000014.D01.S002Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A003.P000014.D02.S002Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A003.P000015.D02.S002Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A003.P000016.D01.S001Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A003.P000017.D01.S001Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A003.P000018.D01.S001Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A003.P000019.D01.S001Aneurysms.mha
# an #:  1
# an #:  2
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A003.P000019.D02.S002Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A003.P000022.D01.S003Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A003.P000022.D01.S004Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A003.P000023.D01.S001Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A003.P000024.D01.S001Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A003.P000025.D01.S003Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A003.P000026.D01.S004Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A003.P000027.D01.S001Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A003.P000028.D01.S002Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A003.P000029.D01.S001Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A003.P000059.D01.S012Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A003.P000064.D01.S002Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A003.P000065.D01.S001Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A003.P000066.D01.S001Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A003.P000067.D01.S001Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A003.P000068.D01.S001Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A003.P000069.D01.S001Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A003.P000074.D01.S001Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A003.P000076.D01.S001Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A003.P000077.D01.S004Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A003.P000078.D01.S001Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A003.P000082.D01.S001Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A003.P000083.D01.S001Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A003.P000084.D01.S001Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A003.P000087.D01.S001Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A003.P000088.D01.S001Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A003.P000089.D01.S001Aneurysms.mha
# an #:  1
# an #:  2
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A003.P000092.D01.S001Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A003.P000098.D01.S001Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A003.P000099.D01.S014Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A003.P000103.D01.S001Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A003.P000103.D01.S005Aneurysms.mha
# an #:  1
# an #:  2
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A003.P000103.D01.S012Aneurysms.mha
# an #:  1
# an #:  2
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A003.P000103.D01.S013Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A003.P000104.D01.S001Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A003.P000104.D01.S002Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A003.P000105.D01.S002Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A003.P000105.D01.S003Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A003.P000106.D01.S001Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A003.P000106.D01.S004Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A003.P000107.D01.S001Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A003.P000108.D01.S002Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A003.P000112.D01.S005Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A003.P000113.D01.S002Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A003.P000122.D01.S001Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A003.P000122.D01.S003Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A003.P000123.D01.S001Aneurysms.mha
# an #:  1
# an #:  2
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A003.P000123.D01.S002Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A003.P000124.D01.S001Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A003.P000125.D01.S001Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A003.P000126.D01.S001Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A003.P000126.D01.S003Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A003.P000127.D01.S002Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A003.P000137.D01.S001Aneurysms.mha
# an #:  1
# an #:  2
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A003.P000142.D01.S001Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A003.P000142.D01.S002Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A003.P000144.D01.S002Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A003.P000145.D01.S001Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A003.P000146.D01.S001Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000021.D01.S003Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000031.D01.S001Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000031.D01.S006Aneurysms.mha
# an #:  1
# an #:  2
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000041.D01.S005Aneurysms.mha
# an #:  1
# an #:  2
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000051.D01.S001Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000071.D01.S004Aneurysms.mha
# an #:  1
# an #:  2
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000091.D01.S004Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000131.D01.S002Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000161.D01.S002Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000191.D01.S001Aneurysms.mha
# an #:  1
# an #:  2
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000191.D01.S002Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000201.D01.S001Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000211.D01.S005Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000211.D01.S006Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000231.D01.S002Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000241.D01.S001Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000241.D01.S003Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000251.D01.S001Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000281.D01.S004Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000291.D01.S004Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000321.D01.S004Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000321.D01.S014Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000441.D01.S003Aneurysms.mha
# an #:  1
# an #:  2
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000741.D01.S002Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000811.D01.S004Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000821.D01.S001Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000831.D01.S002Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000831.D02.S002Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000841.D01.S003Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000881.D01.S005Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000891.D01.S002Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000901.D01.S002Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A003.P000011.D01.S002Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A003.P000011.D02.S009Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A003.P000021.D01.S002Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A003.P000021.D02.S001Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A003.P000071.D01.S004Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A003.P000081.D01.S002Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A003.P000091.D01.S001Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A003.P000101.D01.S001Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A003.P000131.D01.S001Aneurysms.mha
# an #:  1
# an #:  2
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000010.D01.S004Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000030.D01.S001Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000070.D01.S004Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000090.D01.S001Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000110.D01.S004Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000140.D01.S002Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000150.D01.S003Aneurysms.mha
# an #:  1
# an #:  2
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000160.D01.S006Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000180.D01.S002Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000190.D01.S002Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000200.D01.S003Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000210.D01.S004Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000280.D01.S001Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000480.D02.S007Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000540.D01.S002Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000600.D02.S004Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000620.D01.S002Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000640.D01.S001Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000650.D01.S001Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000660.D01.S002Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000660.D01.S003Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000810.D01.S002Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000810.D01.S007Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000820.D01.S001Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000820.D01.S003Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000830.D01.S002Aneurysms.mha
# an #:  1
# an #:  2
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000830.D01.S004Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000830.D01.S005Aneurysms.mha
# an #:  1
# an #:  2
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000840.D01.S001Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000850.D01.S002Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000860.D01.S001Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000870.D01.S003Aneurysms.mha
# an #:  1
# an #:  2
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000880.D01.S004Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000920.D01.S001Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000920.D01.S002Aneurysms.mha
# an #:  1
# an #:  2
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A003.P000010.D01.S004Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A003.P000010.D02.S002Aneurysms.mha
# an #:  1
# an #:  2
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A003.P000020.D02.S001Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A003.P000030.D01.S004Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A003.P000030.D01.S005Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A003.P000060.D01.S001Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A003.P000060.D01.S002Aneurysms.mha
# an #:  1
# an #:  2
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A003.P000070.D01.S001Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A003.P000080.D01.S006Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A003.P000090.D01.S001Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A003.P000100.D01.S008Aneurysms.mha
# an #:  1
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A003.P000130.D01.S001Aneurysms.mha
# an #:  1
# an #:  2
# an #:  3
# saved to:  /home/maze/USAL/libs/new_data/x_train.npy
# saved to:  /home/maze/USAL/libs/new_data/labels_train.npy
# saved to:  /home/maze/USAL/libs/new_data/x_test.npy
# saved to:  /home/maze/USAL/libs/new_data/labels_test.npy
# saved to:  /home/maze/USAL/libs/new_data/x_val.npy
# saved to:  /home/maze/USAL/libs/new_data/labels_val.npy
# saved to:  /home/maze/USAL/libs/new_data/data_seperate.npy

# %%
from main import *
import numpy as np

image_path ='/data/maze/04.AN-AI/01.CVAImage/'
an_path = '/data/maze/04.AN-AI/03.Aneurysms/'
vessel_path = '/data/maze/04.AN-AI/02.CVAVesselMask/'
save_path = '/home/maze/USAL/libs/new_data'

drop_img_list = ['/data/maze/04.AN-AI/01.CVAImage/A002.P000208.D01.S004CVAImage.mha', 
            '/data/maze/04.AN-AI/01.CVAImage/A003.P000143.D01.S001CVAImage.mha']
drop_an_list = ['/data/maze/04.AN-AI/03.Aneurysms/A002.P000208.D01.S004Aneurysms.mha', 
           '/data/maze/04.AN-AI/03.Aneurysms/A003.P000143.D01.S001Aneurysms.mha']
drop_vessel_list = ['/data/maze/04.AN-AI/02.CVAVesselMask/A002.P000208.D01.S004CVAVesselMask.mha', 
              '/data/maze/04.AN-AI/02.CVAVesselMask/A003.P000143.D01.S001CVAVesselMask.mha']

print('load img from the source dir: ', image_path)
img_dir_list = get_file_dir_lists(image_path, drop_img_list)
print('load an from the source dir: ', an_path)
an_dir_list = get_file_dir_lists(an_path, drop_an_list)
print('load vessel from the source dir: ', vessel_path)
vessel_dir_list = get_file_dir_lists(vessel_path, drop_vessel_list)
        
img_train_list, img_val_list, img_test_list = split_dataset(img_list = img_dir_list, split_id = -22)
an_train_list, an_val_list, an_test_list = split_dataset(img_list = an_dir_list, split_id = -23)
vessel_train_list, vessel_val_list, vessel_test_list = split_dataset(img_list = vessel_dir_list, split_id = -27)
        
x_train = []
labels_train = []
x_test = []
labels_test = []
x_val = []
labels_val = []
data_seperate = []
i = 0
print('processing: ', an_train_list[i])
# read the whole image, an_mask and vessel as array
img_array = ImageIo().load(img_train_list[i])
mask_array = ImageIo().load(an_train_list[i])
vessel_array = ImageIo().load(vessel_train_list[i])


small_img_list = []
small_mask_list = []
# normlization raw image array first
img_array = img_norm(img_array, eps = 1e-7)
# nums of An. 1 or 2 or 3
an_nums = int(np.max(mask_array))
for i in range(an_nums):
    print('an #: ', str(i+1))
    # all index for one an            
    one_an_index = np.where(mask_array == (i+1))
    one_an_array = np.array(one_an_index)    # tuple to array
    one_an_array = np.transpose(one_an_array)    # transpose to (n, 3)
    for j in range(len(one_an_array)):
        x = one_an_array[j][0]
        y = one_an_array[j][1]
        z = one_an_array[j][2]
        vessel_array[x, y, z] = 2
    x_mean = get_label_mean(input_tuple = one_an_index, dim = 0)
    y_mean = get_label_mean(input_tuple = one_an_index, dim = 1)
    z_mean = get_label_mean(input_tuple = one_an_index, dim = 2)
    one_an_center = [x_mean, y_mean, z_mean]
    center_int = [int(round(j)) for j in one_an_center]
# Out:
# Using TensorFlow backend.
# load img from the source dir:  /data/maze/04.AN-AI/01.CVAImage/
# /data/maze/04.AN-AI/01.CVAImage/A002.P000208.D01.S004CVAImage.mha  dropped!
# /data/maze/04.AN-AI/01.CVAImage/A003.P000143.D01.S001CVAImage.mha  dropped!
# load an from the source dir:  /data/maze/04.AN-AI/03.Aneurysms/
# /data/maze/04.AN-AI/03.Aneurysms/A002.P000208.D01.S004Aneurysms.mha  dropped!
# /data/maze/04.AN-AI/03.Aneurysms/A003.P000143.D01.S001Aneurysms.mha  dropped!
# load vessel from the source dir:  /data/maze/04.AN-AI/02.CVAVesselMask/
# /data/maze/04.AN-AI/02.CVAVesselMask/A002.P000208.D01.S004CVAVesselMask.mha  dropped!
# /data/maze/04.AN-AI/02.CVAVesselMask/A003.P000143.D01.S001CVAVesselMask.mha  dropped!
# processing:  /data/maze/04.AN-AI/03.Aneurysms/A002.P000002.D01.S003Aneurysms.mha
# an #:  1

# %%
one_an_index
# Out:
# (array([199, 199, 199, ..., 218, 218, 218]),
#  array([266, 266, 266, ..., 280, 281, 281]),
#  array([116, 117, 118, ..., 118, 117, 118]))

# %%
one_an_array
# Out:
# array([[199, 266, 116],
#        [199, 266, 117],
#        [199, 266, 118],
#        ...,
#        [218, 280, 118],
#        [218, 281, 117],
#        [218, 281, 118]])

# %%
print(np.mean(one_an_index[0]), np.mean(one_an_index[1]), np.mean(one_an_index[2]))
# Out:
# 208.78095238095239 269.9013431013431 116.59804639804639

# %%
print(np.mean(one_an_array, axis = 0))
# Out:
# [208.78095238 269.9013431  116.5980464 ]

# %%
mean_dims = np.mean(one_an_array, axis = 0)
type(mean_dims)
# Out:
# numpy.ndarray

# %%
mydict = {}
for i in range(len(mean_dims)):
    key = 'dim' + str(i+1)
    value = mean_dims[i]
    mydict.update({key: value})

# %%
mydict
# Out:
# {'dim1': 208.78095238095239,
#  'dim2': 269.9013431013431,
#  'dim3': 116.59804639804639}

# %%
mydict['dim1']
# Out:
# 208.78095238095239

# %%
drop_list = ['A003.P000143']
drop_img_list = ['/data/maze/04.AN-AI/01.CVAImage/A002.P000208.D01.S004CVAImage.mha', 
            '/data/maze/04.AN-AI/01.CVAImage/A003.P000143.D01.S001CVAImage.mha']
drop_an_list = ['/data/maze/04.AN-AI/03.Aneurysms/A002.P000208.D01.S004Aneurysms.mha', 
           '/data/maze/04.AN-AI/03.Aneurysms/A003.P000143.D01.S001Aneurysms.mha']
drop_vessel_list = ['/data/maze/04.AN-AI/02.CVAVesselMask/A002.P000208.D01.S004CVAVesselMask.mha', 
              '/data/maze/04.AN-AI/02.CVAVesselMask/A003.P000143.D01.S001CVAVesselMask.mha']

# %%
for name in drop_list:
    for i in range(len(drop_img_list)):
        if name in drop_img_list[i]:
            drop_img_list.remove(drop_img_list[i])

# %%
drop_vessel_list
# Out:
# ['/data/maze/04.AN-AI/02.CVAVesselMask/A002.P000208.D01.S004CVAVesselMask.mha',
#  '/data/maze/04.AN-AI/02.CVAVesselMask/A003.P000143.D01.S001CVAVesselMask.mha']

# %%
callbacks = 111
if callbacks != None:
    print('ok')
elif callbacks == None:
    print('no callbakcs')
# Out:
# ok

# %%
import random
random.randint(1,3)
# Out:
# 3

# %%
for i in range(0,10):
    print(random.choice(['xy', 'yz', 'xz']))
# Out:
# yz
# xy
# xz
# xz
# yz
# xz
# xy
# xy
# xy
# xz

# %% [markdown]
# ### 测试2d_to_3d_image_generator

# %%
import sys
sys.path.append('/home/maze/USAL/libs/')
import os
import numpy as np
import random
from data_io.numpy_io import NumpyIo
from mappers.generator_keras import keras_image_generator_2D
from keras.utils import np_utils

data_save_path = '/home/maze/USAL/libs/new_data'
# load dataset
numpyIo = NumpyIo()
x_train = numpyIo.load(path = os.path.join(data_save_path, 'x_train.npy'))
labels_train = numpyIo.load(path = os.path.join(data_save_path, 'labels_train.npy'))
x_test = numpyIo.load(path = os.path.join(data_save_path, 'x_val.npy'))
labels_test = numpyIo.load(path = os.path.join(data_save_path, 'labels_val.npy'))

def image_generator_2Dto3D(data, label, input_generator, class_num, aug_planes = ['xy', 'zy', 'xz'], batch_size = 8, shuffle=True):  #Input dim (n,64,64,64)
    data = np.squeeze(data)
    xy_data = data
    xy_label = label
    xy_batch = input_generator.flow(xy_data, xy_label, batch_size=batch_size, shuffle = shuffle)
    zy_data = data.transpose(0,3,2,1)
    zy_label = label.transpose(0,3,2,1)
    zy_batch = input_generator.flow(zy_data, zy_label, batch_size=batch_size, shuffle = shuffle)
    xz_data = data.transpose(0,1,3,2)
    xz_label = data.transpose(0,1,3,2)
    xz_batch = input_generator.flow(xz_data, xz_label, batch_size=batch_size, shuffle = shuffle)
    while True:
        plane = random.choice(aug_planes)
        if plane == 'xy' or plane == 'yx':
            data_batch, label_batch = next(xy_batch)
            yield(np.expand_dims(data_batch, axis=-1), np_utils.to_categorical(label_batch, class_num))
        elif plane == 'yz' or plane == 'zy':
            data_batch, label_batch = next(zy_batch)
            data_batch = data_batch.transpose(0,3,2,1)
            label_batch = label_batch.tranpose(0,3,2,1)
            yield(np.expand_dims(data_batch, axis=-1), np_utils.to_categorical(label_batch, class_num))
        elif plane == 'xz' or plane == 'zx':
            data_batch, label_batch = next(xz_batch)
            data_batch = data_batch.transpose(0,1,3,2)
            label_batch = label_batch.transpose(0,1,3,2)
            yield(np.expand_dims(data_batch, axis=-1), np_utils.to_categorical(label_batch, class_num))
# Out:
# Using TensorFlow backend.
# load  /home/maze/USAL/libs/new_data/x_train.npy  completed!
# load  /home/maze/USAL/libs/new_data/labels_train.npy  completed!
# load  /home/maze/USAL/libs/new_data/x_val.npy  completed!
# load  /home/maze/USAL/libs/new_data/labels_val.npy  completed!

# %%
keras_datagen = keras_image_generator_2D()
gen = image_generator_2Dto3D(data = x_train, label = labels_train, input_generator = keras_datagen, class_num = 3)

# %%
gen
# Out:
# <generator object image_generator_2Dto3D at 0x7f33e0339888>

# %%
x, y = next(gen)
# Out:
# /home/maze/anaconda3/envs/tensorflow/lib/python3.6/site-packages/keras_preprocessing/image/numpy_array_iterator.py:127: UserWarning: NumpyArrayIterator is set to use the data format convention "channels_last" (channels on axis 3), i.e. expected either 1, 3, or 4 channels on axis 3. However, it was passed an array with shape (346, 64, 64, 64) (64 channels).
#   str(self.x.shape[channels_axis]) + ' channels).')

# %%
x.shape
# Out:
# (8, 64, 64, 64, 1)

# %%
y.shape
# Out:
# (8, 64, 64, 64, 3)

# %%
A = ['dfdokef', 'need remove', 'keep this', 'dont ok', 'this fine', 'remove this', 'that good']
B = ['ok', 'remove']

# %%
for name in B:
    A = list(filter(lambda x: (name not in x), A))
    print(A)
print(A)
# Out:
# ['need remove', 'keep this', 'this fine', 'remove this', 'that good']
# ['keep this', 'this fine', 'that good']
# ['keep this', 'this fine', 'that good']
